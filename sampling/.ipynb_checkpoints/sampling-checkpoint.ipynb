# %% [markdown]
# # Sampling methods for transfer learning
#
# Choosing a sampling method is split into 2 parts:
#
# - What descriptor to use? Eg bond length, bond angles.
#
# - And what selector algorithm to use? Ie what distribution of descriptors do we want to select?

# %%
import ase.io
from pathlib import Path
import numpy as np
import importlib
import descriptor
importlib.reload(descriptor)
from descriptor import *

ROOT_PATH = Path.cwd()
XYZ_DIR = ROOT_PATH / "xyz_files"

# dataset for training the initial (base) model
BASE_XYZ = XYZ_DIR / "A01_ethene_grid_static.xyz"
BASE_N_GEOMETRIES = 100  # number of geometries to use from the base dataset

# dataset for transfer learning
TRANSFER_XYZ = XYZ_DIR / "A02_propene_grid_static.xyz"
TRANSFER_N_GEOMETRIES = 100  # number of geometries to use from the transfer dataset

base_atoms_list = ase.io.read(BASE_XYZ, index=f":{BASE_N_GEOMETRIES}")
transfer_atoms_list = ase.io.read(TRANSFER_XYZ, index=f":{TRANSFER_N_GEOMETRIES}")

# %% [markdown]
# ## 1. Choose descriptor

# %%
DESCRIPTOR = "bond_lengths" # or "bond_angles"

# matrix of descriptors for each geometry
# n*m, where n is the number of geometries and m is the dimension of the descriptor
# eg if we use bond_lengths and propene, m=2 because there's 2 CC bonds in propene
desc_matrix = []
for atom in transfer_atoms_list:
    desc_matrix.append(get_descriptor(DESCRIPTOR,atom))
desc_matrix = np.asarray(desc_matrix)
print(desc_matrix.shape)
# Out:
# (500, 2)

# %% [markdown]
# ## 2. Choose selector
# ## 2a. Furthest point sampling
#
# pip install skmatter
#
# Starting from the first sample, FPS chooses the next sample to be as far away from it as possible.
#
# Repeat until it gets the number of samples that you specified.

# %%
from skmatter.sample_selection import FPS
N_SAMPLES = 50

# FPS selector
selector = FPS(
    n_to_select=N_SAMPLES,
    # int or 'random', default=0
    # Index of the first selection.
    # If "random", picks a random value when fit starts.
    initialize=0,
)
selector.fit(desc_matrix)
selected_idx = selector.selected_idx_

# selected atoms
selected_atoms = [transfer_atoms_list[i] for i in selected_idx]

print("selected indices:", selected_idx)
# Out:
# selected indices: [  0  36 133   9 103  28  29  45  54  38   4  32 118  15  20  37   2   6
#    7  25  63  66  11  13  14  19  33  58  93  96   1   5   8  17  18  21
#   26  41  59  73  92  10  16  50  70  89  90 101 105 132]

# %% [markdown]
# ## 3. Train Base Model

# %%
import copy
import time
import torch
from mace import data, modules, tools
from mace.tools import torch_geometric
from e3nn import o3

# Base model training parameters
BASE_MODEL_MAX_EPOCHS = 50
BASE_MODEL_LR = 1.0e-3
BATCH_SIZE = 4
R_MAX = 5.0
DEVICE = torch.device("cpu")
SEED = 123
VALID_FRACTION = 0.20

# Set random seeds for reproducibility
np.random.seed(SEED)
torch.manual_seed(SEED)

print(f"Base model training config:")
print(f"  Max epochs: {BASE_MODEL_MAX_EPOCHS}")
print(f"  Learning rate: {BASE_MODEL_LR}")
print(f"  Total atoms for training: {len(base_atoms_list)}")
# Out:
# Base model training config:
#   Max epochs: 50
#   Learning rate: 0.001
#   Total atoms for training: 500

# %%
# Create MACE Configuration objects from all atoms
all_configs = data.config_from_atoms_list(
    base_atoms_list,
    energy_key="REF_energy",
    forces_key="REF_forces",
    config_type_weights={"Default": 1.0},
)

# Split into train/validation
base_train_configs, base_valid_configs = data.random_train_valid_split(
    all_configs,
    valid_fraction=VALID_FRACTION,
    seed=SEED,
    work_dir=str(ROOT_PATH),
)

print(f"Train configs: {len(base_train_configs)}")
print(f"Valid configs: {len(base_valid_configs)}")

# Get example to check data
example_atom = base_atoms_list[0]
N_ENERGIES = np.asarray(example_atom.info["REF_energy"]).shape[-1]
print(f"Energy shape: {np.asarray(example_atom.info['REF_energy']).shape}")
print(f"Forces shape: {np.asarray(example_atom.info['REF_forces']).shape}")
print(f"N_ENERGIES: {N_ENERGIES}")
# Out:
# Train configs: 400
# Valid configs: 100
# Energy shape: (1, 3)
# Forces shape: (6, 3, 3)
# N_ENERGIES: 3

# %%
# Create atomic number table and compute atomic energies
z_table_base = tools.get_atomic_number_table_from_zs(
    z for config in all_configs for z in config.atomic_numbers
)

atomic_energies_dict_base = data.compute_average_E0s(base_train_configs, z_table_base)
atomic_energies_base = np.array([atomic_energies_dict_base[z] for z in z_table_base.zs], dtype=np.float64)

print(f"Atomic numbers: {[int(z) for z in z_table_base.zs]}")
print(f"Atomic energies: {atomic_energies_dict_base}")
# Out:
# Atomic numbers: [1, 6]
# Atomic energies: {np.int64(1): np.float64(-423.2511808575362), np.int64(6): np.float64(-211.62559042876777)}

# %%
# Convert Configuration objects to graph data objects
base_train_set = [
    data.AtomicData.from_config(config, z_table=z_table_base, cutoff=R_MAX)
    for config in base_train_configs
]
base_valid_set = [
    data.AtomicData.from_config(config, z_table=z_table_base, cutoff=R_MAX)
    for config in base_valid_configs
]

# Create data loaders
base_train_loader = torch_geometric.dataloader.DataLoader(
    base_train_set,
    batch_size=BATCH_SIZE,
    shuffle=True,
    drop_last=False,
)
base_valid_loader = torch_geometric.dataloader.DataLoader(
    base_valid_set,
    batch_size=BATCH_SIZE,
    shuffle=False,
    drop_last=False,
)

avg_num_neighbors_base = modules.compute_avg_num_neighbors(base_train_loader)
print(f"Average neighbors: {float(avg_num_neighbors_base)}")
# Out:
# Average neighbors: 5.0

# %%
# Build the base model
base_model = modules.AutoencoderExcitedMACE(
    r_max=R_MAX,
    num_bessel=4,
    num_polynomial_cutoff=3,
    num_permutational_invariant=4,
    n_energies=N_ENERGIES,
    max_ell=2,
    interaction_cls=modules.interaction_classes["RealAgnosticResidualInteractionBlock"],
    interaction_cls_first=modules.interaction_classes["RealAgnosticResidualInteractionBlock"],
    num_interactions=1,
    num_elements=len(z_table_base),
    hidden_irreps=o3.Irreps("4x0e + 4x1o"),
    MLP_irreps=o3.Irreps("4x0e"),
    atomic_energies=atomic_energies_base,
    avg_num_neighbors=float(avg_num_neighbors_base),
    atomic_numbers=[int(z) for z in z_table_base.zs],
    correlation=1,
    gate=modules.gate_dict["silu"],
    radial_MLP=[32, 32],
    compute_nacs=False,
    compute_socs=False,
    nac_num=0,
    soc_num=0,
).to(DEVICE)

print(f"Base model class: {base_model.__class__.__name__}")
print(f"Total parameters: {tools.count_parameters(base_model)}")
# Out:
# /home/lim_yt/micromamba/envs/xmace311/lib/python3.11/ast.py:418: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   return visitor(node)
# /home/lim_yt/micromamba/envs/xmace311/lib/python3.11/ast.py:418: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   return visitor(node)
# /home/lim_yt/micromamba/envs/xmace311/lib/python3.11/ast.py:418: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   return visitor(node)
# /home/lim_yt/micromamba/envs/xmace311/lib/python3.11/ast.py:418: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   return visitor(node)
# /home/lim_yt/micromamba/envs/xmace311/lib/python3.11/ast.py:418: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   return visitor(node)
# /home/lim_yt/micromamba/envs/xmace311/lib/python3.11/ast.py:418: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   return visitor(node)
# Base model class: AutoencoderExcitedMACE
# Total parameters: 54269
# /home/lim_yt/micromamba/envs/xmace311/lib/python3.11/ast.py:418: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   return visitor(node)
# /home/lim_yt/micromamba/envs/xmace311/lib/python3.11/ast.py:418: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   return visitor(node)

# %%
# Define loss function and training helper
loss_fn = modules.InvariantsWeightedEnergyForcesNacsDipoleLoss(
    energy_weight=1.0,
    forces_weight=5.0,
    dipoles_weight=0.0,
    nacs_weight=0.0,
    socs_weight=0.0,
)

def add_autoencoder_targets(active_model, batch, output):
    """Add autoencoder targets to output for loss computation."""
    centred_reference_energy = (
        batch["energy"] - output["e0s"] - output["pair_energy"]
    ).unsqueeze(-1)
    
    output["encoded_energy"] = active_model.perm_encoder(centred_reference_energy)
    output["decoded_energy"] = (
        active_model.perm_decoder(output["encoded_energy"])
        + output["e0s"]
        + output["pair_energy"]
    )
    return output

print("Loss function defined")
# Out:
# Loss function defined

# %%
# Initialize optimizer and train base model
base_optimizer = torch.optim.Adam(base_model.parameters(), lr=BASE_MODEL_LR)
base_history = []

for epoch in range(BASE_MODEL_MAX_EPOCHS):
    epoch_start = time.time()
    base_model.train()
    train_losses = []

    for batch in base_train_loader:
        batch = batch.to(DEVICE)
        base_optimizer.zero_grad(set_to_none=True)

        output = base_model(
            batch.to_dict(),
            training=True,
            compute_force=True,
            compute_virials=False,
            compute_stress=False,
        )
        output = add_autoencoder_targets(base_model, batch, output)

        loss = loss_fn(ref=batch, pred=output)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(base_model.parameters(), max_norm=10.0)
        base_optimizer.step()
        train_losses.append(float(loss.detach().cpu()))

    base_model.eval()
    valid_losses = []
    for batch in base_valid_loader:
        batch = batch.to(DEVICE)
        output = base_model(
            batch.to_dict(),
            training=False,
            compute_force=True,
            compute_virials=False,
            compute_stress=False,
        )
        output = add_autoencoder_targets(base_model, batch, output)

        loss = loss_fn(ref=batch, pred=output)
        valid_losses.append(float(loss.detach().cpu()))

    row = {
        "stage": "base_model",
        "epoch": epoch + 1,
        "train_loss": float(np.mean(train_losses)),
        "valid_loss": float(np.mean(valid_losses)),
        "seconds": round(time.time() - epoch_start, 2),
    }
    base_history.append(row)
    
    if (epoch + 1) % 10 == 0 or epoch == 0:
        print(row)

print(f"\nBase model training complete after {BASE_MODEL_MAX_EPOCHS} epochs")
print(f"Final train loss: {base_history[-1]['train_loss']:.6f}")
print(f"Final valid loss: {base_history[-1]['valid_loss']:.6f}")
# Out:
# {'stage': 'base_model', 'epoch': 1, 'train_loss': 23.71270546913147, 'valid_loss': 27.064121055603028, 'seconds': 43.82}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 24
#      20         )
#      21         output = add_autoencoder_targets(base_model, batch, output)
#      22
#      23         loss = loss_fn(ref=batch, pred=output)
# ---> 24         loss.backward()
#      25         torch.nn.utils.clip_grad_norm_(base_model.parameters(), max_norm=10.0)
#      26         base_optimizer.step()
#      27         train_losses.append(float(loss.detach().cpu()))
#
# File ~/micromamba/envs/xmace311/lib/python3.11/site-packages/torch/_tensor.py:631, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     621 if has_torch_function_unary(self):
#     622     return handle_torch_function(
#     623         Tensor.backward,
#     624         (self,),
#    (...)    629         inputs=inputs,
#     630     )
# --> 631 torch.autograd.backward(
#     632     self, gradient, retain_graph, create_graph, inputs=inputs
#     633 )
#
# File ~/micromamba/envs/xmace311/lib/python3.11/site-packages/torch/autograd/__init__.py:379, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     374     retain_graph = create_graph
#     376 # The reason we repeat the same comment below is that
#     377 # some Python versions print out the first line of a multi-line function
#     378 # calls in the traceback and some print out the last line
# --> 379 _engine_run_backward(
#     380     tensors,
#     381     grad_tensors_,
#     382     retain_graph,
#     383     create_graph,
#     384     inputs_tuple,
#     385     allow_unreachable=True,
#     386     accumulate_grad=True,
#     387 )
#
# File ~/micromamba/envs/xmace311/lib/python3.11/site-packages/torch/autograd/graph.py:882, in _engine_run_backward(t_outputs, *args, **kwargs)
#     879 torch._C._stash_obj_in_tls("context", contextvars.copy_context())
#     881 try:
# --> 882     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     883         t_outputs, *args, **kwargs
#     884     )  # Calls into the C++ engine to run the backward pass
#     885 finally:
#     886     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# ## 4. Naive Transfer Learning on Selected Atoms
#
# Now perform transfer learning using the selected atoms instead of all atoms. The base model trained above serves as the initialization.

# %%
# Transfer learning parameters
TRANSFER_MAX_EPOCHS = 50
TRANSFER_LR = 5.0e-4

# Create MACE Configuration objects from selected atoms
transfer_configs = data.config_from_atoms_list(
    selected_atoms,
    energy_key="REF_energy",
    forces_key="REF_forces",
    config_type_weights={"Default": 1.0},
)

# Split selected configurations into train/validation sets
transfer_train_configs, transfer_valid_configs = data.random_train_valid_split(
    transfer_configs,
    valid_fraction=VALID_FRACTION,
    seed=SEED,
    work_dir=str(ROOT_PATH),
)

print(f"Transfer learning config:")
print(f"  Max epochs: {TRANSFER_MAX_EPOCHS}")
print(f"  Learning rate: {TRANSFER_LR}")
print(f"  Train configs: {len(transfer_train_configs)}")
print(f"  Valid configs: {len(transfer_valid_configs)}")

# %%
# Convert Configuration objects to graph data objects
transfer_train_set = [
    data.AtomicData.from_config(config, z_table=z_table_base, cutoff=R_MAX)
    for config in transfer_train_configs
]
transfer_valid_set = [
    data.AtomicData.from_config(config, z_table=z_table_base, cutoff=R_MAX)
    for config in transfer_valid_configs
]

# Create data loaders for transfer learning
transfer_train_loader = torch_geometric.dataloader.DataLoader(
    transfer_train_set,
    batch_size=BATCH_SIZE,
    shuffle=True,
    drop_last=False,
)
transfer_valid_loader = torch_geometric.dataloader.DataLoader(
    transfer_valid_set,
    batch_size=BATCH_SIZE,
    shuffle=False,
    drop_last=False,
)

print(f"Transfer learning dataloaders created")

# %%
# Make a deep copy of the base model for transfer learning
transfer_model = copy.deepcopy(base_model).to(DEVICE)
transfer_model.eval()

# Initialize optimizer for naive transfer learning (all parameters trainable)
transfer_optimizer = torch.optim.Adam(transfer_model.parameters(), lr=TRANSFER_LR)
transfer_trainable_count = sum(param.numel() for param in transfer_model.parameters() if param.requires_grad)

print(f"Transfer model class: {transfer_model.__class__.__name__}")
print(f"Transfer model parameters: {tools.count_parameters(transfer_model)}")
print(f"Transfer trainable parameters: {transfer_trainable_count}")
print(f"All parameters will be fine-tuned (naive transfer learning)")

# %%
# Transfer learning training loop
transfer_history = []

for epoch in range(TRANSFER_MAX_EPOCHS):
    epoch_start = time.time()
    transfer_model.train()
    train_losses = []

    for batch in transfer_train_loader:
        batch = batch.to(DEVICE)
        transfer_optimizer.zero_grad(set_to_none=True)

        output = transfer_model(
            batch.to_dict(),
            training=True,
            compute_force=True,
            compute_virials=False,
            compute_stress=False,
        )
        output = add_autoencoder_targets(transfer_model, batch, output)

        loss = loss_fn(ref=batch, pred=output)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(transfer_model.parameters(), max_norm=10.0)
        transfer_optimizer.step()
        train_losses.append(float(loss.detach().cpu()))

    transfer_model.eval()
    valid_losses = []
    for batch in transfer_valid_loader:
        batch = batch.to(DEVICE)
        output = transfer_model(
            batch.to_dict(),
            training=False,
            compute_force=True,
            compute_virials=False,
            compute_stress=False,
        )
        output = add_autoencoder_targets(transfer_model, batch, output)

        loss = loss_fn(ref=batch, pred=output)
        valid_losses.append(float(loss.detach().cpu()))

    row = {
        "stage": "transfer_learning_naive",
        "epoch": epoch + 1,
        "train_loss": float(np.mean(train_losses)),
        "valid_loss": float(np.mean(valid_losses)),
        "seconds": round(time.time() - epoch_start, 2),
    }
    transfer_history.append(row)
    
    if (epoch + 1) % 10 == 0 or epoch == 0:
        print(row)

print(f"\nTransfer learning complete after {TRANSFER_MAX_EPOCHS} epochs")
print(f"Final train loss: {transfer_history[-1]['train_loss']:.6f}")
print(f"Final valid loss: {transfer_history[-1]['valid_loss']:.6f}")

# %%
import matplotlib.pyplot as plt

# Plot transfer learning training history
epochs = [row["epoch"] for row in transfer_history]
train_losses = [row["train_loss"] for row in transfer_history]
valid_losses = [row["valid_loss"] for row in transfer_history]

fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(epochs, train_losses, marker="o", linewidth=1.8, label="Train loss", alpha=0.8)
ax.plot(epochs, valid_losses, marker="s", linewidth=1.8, label="Validation loss", alpha=0.8)
ax.set_xlabel("Epoch")
ax.set_ylabel("Loss")
ax.set_title(f"Transfer Learning Loss (Naive, {TRANSFER_MAX_EPOCHS} epochs)")
ax.grid(True, alpha=0.3)
ax.legend()
fig.tight_layout()
plt.show()

print(f"Training completed. Total training time: {sum(row['seconds'] for row in transfer_history):.1f}s")
